# %% [markdown]
# <a href="https://colab.research.google.com/github/MansurovSh/Python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random as rd
lst = ['robot'] * 10
lst += ['human'] * 10
rd.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  robot
# 2  human
# 3  robot
# 4  human

# %%
# data.loc[data['whoAmI'] == 'robot','robot'] = 1
# data.loc[data['whoAmI'] != 'robot', 'robot'] = 0
# data.loc[data['whoAmI'] == 'human','human'] = 1
# data.loc[data['whoAmI'] != 'human', 'human'] = 0
# data

# %%
list = []
len = data.shape[0]
columns = ['robot','human']
for i in range(len):
  if data['whoAmI'][i] == columns[0]:
    list.append([1,0])
  else:
    list.append([0,1])
df = pd.DataFrame(data= list,columns=columns)
df
# Out:
#     robot  human
# 0       0      1
# 1       1      0
# 2       0      1
# 3       1      0
# 4       0      1
# 5       0      1
# 6       1      0
# 7       1      0
# 8       0      1
# 9       1      0
# 10      0      1
# 11      1      0
# 12      0      1
# 13      1      0
# 14      0      1
# 15      1      0
# 16      1      0
# 17      0      1
# 18      1      0
# 19      0      1
